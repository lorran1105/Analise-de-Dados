# %%
import wbdata
import pandas as pd
from datetime import datetime

# -------------------------------------------------------
#  Indicadores a coletar
# -------------------------------------------------------
indicadores = {
    # Econômicos

    'NY.GDP.MKTP.CD': 'PIB_USD',         # PIB (em USD)
    'NY.GNP.PCAP.CD': 'Renda_per_capita', # Renda per capita
    'FP.CPI.TOTL.ZG': 'Inflacao',         # Inflação
    'NY.GDP.MKTP.KD.ZG': 'Crescimento_PIB', # Crescimento do PIB
    'BX.KLT.DINV.CD.WD': 'Invest_Estrangeiro', # Investimento Estrangeiro

    # Ambientais

    #'EN.ATM.CO2E.PC': 'CO2_per_capita',  # CO2 per capita VALIDAR NÃO FUNCIONA
    'AG.LND.FRST.ZS': 'Florestas_percentual', # Percentual de florestas
    #'SH.H2O.SAFE.ZS': 'Agua_Potavel',     # Acesso à água potável VALIDAR NÃO FUNCIONA
    'EG.USE.PCAP.KG.OE': 'Energia_per_capita', # Consumo de energia per capita

    # Segurança e sociais

   'MS.MIL.XPND.GD.ZS': 'Gasto_Militar_PIB', # Gasto militar como % do PIB
   'VC.IHR.PSRC.P5': 'Taxa_Homicidios_100mil', # Taxa de homicídios por 100 mil habitantes
   'SL.UEM.TOTL.ZS': 'Desemprego_percentual', # Taxa de desemprego
   'SP.DYN.LE00.IN': 'Expectativa_vida',   # Expectativa de vida
   'SH.XPD.CHEX.GD.ZS': 'Gasto_saude_PIB'   # Gasto com saúde como % do PIB
}

# -------------------------------------------------------
# Coleta os dados (todos os anos disponíveis)
# -------------------------------------------------------
print("Baixando os dados disponíveis da API...")

try:
    # Chama a API do Banco Mundial sem o parâmetro data_date para pegar todos os anos
    df = wbdata.get_dataframe(indicators=indicadores)
    
except RuntimeError as e:
    print(f"Erro ao buscar dados: {e}")
    # Caso um erro ocorra, exiba a lista de indicadores que causaram o problema
    print("\nIndicadores problemáticos:")
    print(indicadores)

# -------------------------------------------------------
#  Limpeza e formatação
# -------------------------------------------------------
print(" Limpando e formatando os dados...")

# Resetando o índice para transformar as datas em colunas
df = df.reset_index()

# Converte a coluna 'date' para o formato datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# -------------------------------------------------------
# Exporta
# -------------------------------------------------------
print("Salvando em CSV...")

# Salva os dados em um arquivo CSV
df.to_csv("df_indicadores_mundiais_todos_anos.csv", index=False)

# -------------------------------------------------------
# Visualiza
# -------------------------------------------------------
print("Dados prontos! Veja os primeiros registros:")
print(df.head())
# Out:
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# Key '5821199396759509202' not in persistent cache.
# Key '-2312581806856949270' not in persistent cache.
# Key '1185079425766986337' not in persistent cache.
# Key '1474376052356095223' not in persistent cache.
# Key '-7396087267890121730' not in persistent cache.
# Key '7352239522260652827' not in persistent cache.
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-2753769605798110827' not in persistent cache.
# Key '-4131319690225412153' not in persistent cache.
# Key '-4112289678482049755' not in persistent cache.
# Key '4704148940314870606' not in persistent cache.
# Key '-152741824258256920' not in persistent cache.
# Key '-4368737713632465380' not in persistent cache.
# Key '5930682849706587288' not in persistent cache.
# Key '2804219117043754173' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '4482485287285538721' not in persistent cache.
# Key '3636673136093501702' not in persistent cache.
# Key '-5429808817967955319' not in persistent cache.
# Key '6152874567369630781' not in persistent cache.
# Key '-5678366593579282657' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '-6024281344734667758' not in persistent cache.
# Key '8126059818038258056' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '7216969737557790065' not in persistent cache.
# Key '-3622210686803766547' not in persistent cache.
# Key '6813346089747055885' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Key '4096718660594114671' not in persistent cache.
# Key '1917311493170717918' not in persistent cache.
# Key '9002566940191751590' not in persistent cache.
# Key '-4207709465159731617' not in persistent cache.
# Key '-5484095601637503727' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '-2764317961925181500' not in persistent cache.
# Key '1004511245418653688' not in persistent cache.
# Key '-5159735871297972694' not in persistent cache.
# Key '1097469567276782193' not in persistent cache.
# Key '6531511980696888744' not in persistent cache.
# Key '841179763551856418' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '2066745564384056460' not in persistent cache.
# Key '584731728401440793' not in persistent cache.
# ...
# Key '-5142615206117597635' not in persistent cache.
# Key '4759921283637628336' not in persistent cache.
# Key '3104024822049923661' not in persistent cache.
# Key '7893518722736884512' not in persistent cache.
# Key '7872236210292414565' not in persistent cache.
# Key '8634416550116044722' not in persistent cache.
# Key '726052507972471285' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '322428860161737105' not in persistent cache.
# Key '117603621545617433' not in persistent cache.
# Key '765299908749773442' not in persistent cache.
# Key '-7042428996087553748' not in persistent cache.
# Key '-6357522417412776921' not in persistent cache.
# Key '4353166695744530296' not in persistent cache.
# Key '-950822637742741686' not in persistent cache.
# Key '351127904811968589' not in persistent cache.
# Key '2640887635176956903' not in persistent cache.
# Key '7877355303535025312' not in persistent cache.
# Key '1871678572881363413' not in persistent cache.
# Key '-3160263272343808678' not in persistent cache.
# Key '-5084508735838266740' not in persistent cache.
# Key '7326964392047271528' not in persistent cache.
# Key '-103141172255882278' not in persistent cache.
# Key '-6095521683191923418' not in persistent cache.
# Key '-2405230427238153592' not in persistent cache.
# Key '4645816769152335991' not in persistent cache.
# Key '-4887376330643013153' not in persistent cache.
# Key '-697613699022594717' not in persistent cache.
# Key '-3360027999672872209' not in persistent cache.
# Key '7623678434681087227' not in persistent cache.
# Key '4746023872984169608' not in persistent cache.
# Key '-878181879370927366' not in persistent cache.
# Key '2981360772589076324' not in persistent cache.
# Key '-2685780010535116138' not in persistent cache.
# Key '-8850027127251742520' not in persistent cache.
# Key '-2934337786146443476' not in persistent cache.
# Key '-9098584902863069858' not in persistent cache.
# Key '-3053272620069130328' not in persistent cache.
# Key '-6169553358498405048' not in persistent cache.
# Key '-7576655448238454379' not in persistent cache.
# Key '3012365758298871009' not in persistent cache.
# Key '3800004617960298972' not in persistent cache.
# Key '-1943590420361417417' not in persistent cache.
# Key '-4224573473109567273' not in persistent cache.
# Key '8037697279121554148' not in persistent cache.
# Key '3841498374709621374' not in persistent cache.
# Key '-2322748742007005008' not in persistent cache.
# Key '4901354423494437882' not in persistent cache.
# Key '1219064098897197052' not in persistent cache.
# Key '2768405479191228234' not in persistent cache.
# Key '-1527235696406394145' not in persistent cache.
# Key '7576057272244817973' not in persistent cache.
# Key '5304978071305172062' not in persistent cache.
# Key '1055732617030399782' not in persistent cache.
# Key '-415044692497960608' not in persistent cache.
# Key '5207663879860905783' not in persistent cache.
# Key '6513996234973374316' not in persistent cache.
# Key '-8314129000898152092' not in persistent cache.
# Key '-3423253563194813851' not in persistent cache.
# Key '-8157230289037877406' not in persistent cache.
# Key '3415331625567912511' not in persistent cache.
# Key '3097071092019604340' not in persistent cache.
# Key '-2159297079031398388' not in persistent cache.
# Key '1729530949901786436' not in persistent cache.
# Key '5145314702602080657' not in persistent cache.
# Key '528920210369121965' not in persistent cache.
# Key '-680749691072759061' not in persistent cache.
# Key '5483497425643867321' not in persistent cache.
# Key '-612250175677527884' not in persistent cache.
# Key '-3514912626945866503' not in persistent cache.
# Key '2814502494577611055' not in persistent cache.
# Key '-1902849043880982763' not in persistent cache.
# Key '-6137874944998553621' not in persistent cache.
# Key '-841777939545492824' not in persistent cache.
# Key '4211321206783803504' not in persistent cache.
# Key '-219109684196022886' not in persistent cache.
# Key '5945137432520603496' not in persistent cache.
# Key '-6991080321870484828' not in persistent cache.
# Key '3274010845996882019' not in persistent cache.
# Key '-593220163934165486' not in persistent cache.
# Key '-8766909732252948279' not in persistent cache.
# Key '6371848611993797339' not in persistent cache.
# Key '3530458881147297644' not in persistent cache.
# Key '5248600464449670705' not in persistent cache.
# Key '-758554294895744322' not in persistent cache.
# Key '4156887602017766' not in persistent cache.
# Key '4896778963644704825' not in persistent cache.
# Key '-2421599947271102076' not in persistent cache.
# Key '-11421044687226428' not in persistent cache.
# Key '2411613335158703019' not in persistent cache.
# Key '5664065605992199970' not in persistent cache.
# Key '-4797747435342951076' not in persistent cache.
# Key '-4338167073373453136' not in persistent cache.
# Key '-3365147092915482956' not in persistent cache.
# Key '-5054195470493366701' not in persistent cache.
# Key '-5932190201325126148' not in persistent cache.
# Key '8570152141748890426' not in persistent cache.
# Key '1973774350038430144' not in persistent cache.
# Key '4227272969594050295' not in persistent cache.
# Key '-6039023739734456553' not in persistent cache.
# Key '8420423938042322151' not in persistent cache.
# Key '-1278677920795066807' not in persistent cache.
# Baixando os dados disponíveis da API...
# WARNING:shelved_cache.persistent_cache:Key '125223376982169829' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6179153494560330280' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7396087267890121730' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1214377967230023286' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '103706210892158705' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6890599515383916652' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '851838353088877174' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2984787297392086822' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4746023872984169608' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6531511980696888744' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6530777492305062600' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3167941609735915680' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5185848538860312544' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3200308259430146826' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7205203882899636329' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6616140606567488609' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1615655432030625079' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1871678572881363413' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2764317961925181500' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3693790363014094914' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3104024822049923661' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5330166752772398129' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3053272620069130328' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2618805430450669352' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6125705612868936145' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-245058668551002250' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2998039563717850591' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4759921283637628336' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7654025639849189234' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6169553358498405048' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3800004617960298972' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3499107060325088' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4353166695744530296' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8278990798185512605' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3012365758298871009' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-947869518536223311' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2137105831905227414' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3874000161632894411' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3423253563194813851' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5493498234639195399' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4638160774489993137' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1069630027683858510' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4901354423494437882' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2405230427238153592' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1917311493170717918' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8172776543239308547' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-415044692497960608' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7352239522260652827' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-697613699022594717' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1474376052356095223' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '117603621545617433' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5207663879860905783' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8314129000898152092' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '9126672263672372013' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6024281344734667758' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7872236210292414565' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1055732617030399782' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8157230289037877406' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1811097238224513860' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6152874567369630781' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '765299908749773442' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3671811338806141189' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-152741824258256920' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4131319690225412153' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4096718660594114671' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5930682849706587288' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4156887602017766' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5142615206117597635' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1185079425766986337' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3636673136093501702' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6884216607463367225' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '528920210369121965' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8413678324188293031' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2505211830186783489' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7326964392047271528' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2753769605798110827' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2981360772589076324' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3363639741296944096' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5304978071305172062' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4474829292623195867' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6513996234973374316' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2066745564384056460' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7623678434681087227' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4704148940314870606' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4224573473109567273' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5438194608744155097' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1199500594462878374' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4705841508754470855' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5841818256554889277' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4371040947026528887' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6077647431909924827' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2017976299460367896' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-9179997070253785964' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1658888764773339988' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3201108625087764315' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8114328469414611462' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4049097498157845417' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6435968262820946783' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1793206169690097495' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3011707977757178331' not in persistent cache.
#  Limpando e formatando os dados...
# Salvando em CSV...
# Dados prontos! Veja os primeiros registros:
#        country       date  PIB_USD  Renda_per_capita  Inflacao  \
# 0  Afghanistan 1960-01-01      NaN               NaN       NaN
# 1  Afghanistan 1961-01-01      NaN               NaN       NaN
# 2  Afghanistan 1962-01-01      NaN               NaN       NaN
# 3  Afghanistan 1963-01-01      NaN               NaN       NaN
# 4  Afghanistan 1964-01-01      NaN               NaN       NaN
#
#    Crescimento_PIB  Invest_Estrangeiro  Florestas_percentual  \
# 0              NaN                 NaN                   NaN
# 1              NaN                 NaN                   NaN
# 2              NaN                 NaN                   NaN
# 3              NaN                 NaN                   NaN
# 4              NaN                 NaN                   NaN
#
#    Energia_per_capita  Gasto_Militar_PIB  Taxa_Homicidios_100mil  \
# 0                 NaN                NaN                     NaN
# 1                 NaN                NaN                     NaN
# 2                 NaN                NaN                     NaN
# 3                 NaN                NaN                     NaN
# 4                 NaN                NaN                     NaN
#
#    Desemprego_percentual  Expectativa_vida  Gasto_saude_PIB
# 0                    NaN            32.799              NaN
# 1                    NaN            33.291              NaN
# 2                    NaN            33.757              NaN
# 3                    NaN            34.201              NaN
# 4                    NaN            34.673              NaN

# %%
# ==========================================================
# Importando bibliotecas necessárias
# ==========================================================
from sqlalchemy import create_engine

# ==========================================================
# Definindo as credenciais do banco (Render)
# ==========================================================
host = "dpg-d39eabemcj7s73f0vcv0-a.oregon-postgres.render.com"
port = "5432"
database = "projeto_paises"
user = "user"
password = "QP7z5ILeinmGr76fDpSeNIiqLOeXL4WE"

# ==========================================================
# Criando a conexão com o PostgreSQL usando SQLAlchemy
# ==========================================================
engine = create_engine(
    f"postgresql://{user}:{password}@{host}:{port}/{database}"
)


# ==========================================================
# Salvando no banco (tabela: paises)
# if_exists:
#   - 'replace' -> apaga e recria a tabela
#   - 'append' -> adiciona os dados
# ==========================================================
df.to_sql("tbl_dados_banco_mundial", engine, if_exists="replace", index=False)

print("✅ Dados salvos no banco Render com sucesso!")
# Out:
# ✅ Dados salvos no banco Render com sucesso!
