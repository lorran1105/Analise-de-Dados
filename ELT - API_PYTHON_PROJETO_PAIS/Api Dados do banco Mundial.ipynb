# %%
import wbdata
import pandas as pd
from datetime import datetime

# -------------------------------------------------------
#  Indicadores a coletar
# -------------------------------------------------------
indicadores = {
    # Econômicos

    'NY.GDP.MKTP.CD': 'PIB_USD',         # PIB (em USD)
    'NY.GNP.PCAP.CD': 'Renda_per_capita', # Renda per capita
    'FP.CPI.TOTL.ZG': 'Inflacao',         # Inflação
    'NY.GDP.MKTP.KD.ZG': 'Crescimento_PIB', # Crescimento do PIB
    'BX.KLT.DINV.CD.WD': 'Invest_Estrangeiro', # Investimento Estrangeiro

    # Ambientais

    #'EN.ATM.CO2E.PC': 'CO2_per_capita',  # CO2 per capita VALIDAR NÃO FUNCIONA
    'AG.LND.FRST.ZS': 'Florestas_percentual', # Percentual de florestas
    #'SH.H2O.SAFE.ZS': 'Agua_Potavel',     # Acesso à água potável VALIDAR NÃO FUNCIONA
    'EG.USE.PCAP.KG.OE': 'Energia_per_capita', # Consumo de energia per capita

    # Segurança e sociais

   'MS.MIL.XPND.GD.ZS': 'Gasto_Militar_PIB', # Gasto militar como % do PIB
   'VC.IHR.PSRC.P5': 'Taxa_Homicidios_100mil', # Taxa de homicídios por 100 mil habitantes
   'SL.UEM.TOTL.ZS': 'Desemprego_percentual', # Taxa de desemprego
   'SP.DYN.LE00.IN': 'Expectativa_vida',   # Expectativa de vida
   'SH.XPD.CHEX.GD.ZS': 'Gasto_saude_PIB'   # Gasto com saúde como % do PIB
}

# -------------------------------------------------------
# Coleta os dados (todos os anos disponíveis)
# -------------------------------------------------------
print("Baixando os dados disponíveis da API...")

try:
    # Chama a API do Banco Mundial sem o parâmetro data_date para pegar todos os anos
    df = wbdata.get_dataframe(indicators=indicadores)
    
except RuntimeError as e:
    print(f"Erro ao buscar dados: {e}")
    # Caso um erro ocorra, exiba a lista de indicadores que causaram o problema
    print("\nIndicadores problemáticos:")
    print(indicadores)

# -------------------------------------------------------
#  Limpeza e formatação
# -------------------------------------------------------
print(" Limpando e formatando os dados...")

# Resetando o índice para transformar as datas em colunas
df = df.reset_index()

# Converte a coluna 'date' para o formato datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# -------------------------------------------------------
# Exporta
# -------------------------------------------------------
print("Salvando em CSV...")

# Salva os dados em um arquivo CSV
df.to_csv("df_indicadores_mundiais_todos_anos.csv", index=False)

# -------------------------------------------------------
# Visualiza
# -------------------------------------------------------
print("Dados prontos! Veja os primeiros registros:")
print(df.head())
# Out:
# Key '-7694437903385842267' not in persistent cache.
# Key '-1746871428592387251' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '-3059043584793063638' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '5548308604572111642' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '8389361212230798029' not in persistent cache.
# Key '8496234110338532716' not in persistent cache.
# Key '1913549162205886303' not in persistent cache.
# Key '4645091030622532557' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '487224120098595183' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-7834810854940634702' not in persistent cache.
# Key '3692837871719999548' not in persistent cache.
# Key '-2140381396921896688' not in persistent cache.
# Key '2704783454678347705' not in persistent cache.
# Key '-4267518026081720340' not in persistent cache.
# Key '7541679746743938621' not in persistent cache.
# Key '-7359006144779533422' not in persistent cache.
# Key '-3528973880609029871' not in persistent cache.
# Key '-5689074698635785879' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '1025442618687200942' not in persistent cache.
# Key '-4206590758098085982' not in persistent cache.
# Key '3169499688258497142' not in persistent cache.
# Key '-1476678300813595276' not in persistent cache.
# Key '-2894184667838684894' not in persistent cache.
# Key '7332420673137485634' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-4369922239964883252' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7804738433950688413' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '4237429949400292028' not in persistent cache.
# Key '-6833223677952676464' not in persistent cache.
# Key '-8909835688173731243' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '-6010365731603318904' not in persistent cache.
# Key '-1111600034360892376' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '5258946151310052187' not in persistent cache.
# Key '5495915499180767760' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '7949454732980978489' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-2951192395614749173' not in persistent cache.
# Key '5822318103821154837' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '8339148329840236706' not in persistent cache.
# Key '-1953883477954253198' not in persistent cache.
# Key '-2342727041276001367' not in persistent cache.
# Key '2002991771393026221' not in persistent cache.
# Key '3869702113533103213' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '4274991165466337540' not in persistent cache.
# Key '-359367578055473263' not in persistent cache.
# Key '4760939361453863815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '1180000441729143934' not in persistent cache.
# Key '8556090888085727058' not in persistent cache.
# Key '-485077132884188172' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '2508318134774344510' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '-7729318241103231283' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-268203859524938574' not in persistent cache.
# Key '-6657214461494211938' not in persistent cache.
# Key '8800788336716972881' not in persistent cache.
# Key '8247984611309702017' not in persistent cache.
# Key '-4747190039750152207' not in persistent cache.
# Key '8709624618186438192' not in persistent cache.
# Key '3439759592405251650' not in persistent cache.
# Key '298841276928402327' not in persistent cache.
# Key '-3705838122422133536' not in persistent cache.
# Key '-2681292415122170463' not in persistent cache.
# Key '-6803345946525668317' not in persistent cache.
# Key '-4987909236512066995' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-3506388332823479911' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# Key '-8848908420190096885' not in persistent cache.
# Key '-1511159694031598159' not in persistent cache.
# Key '8061186469101104038' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '135509795061605057' not in persistent cache.
# Key '2392469803943013252' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-8471842394303570223' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-1700474917672077148' not in persistent cache.
# Key '-6413254182386569163' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '936479539669877367' not in persistent cache.
# Key '-3846211073976925971' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '1644758297689229805' not in persistent cache.
# Key '2144953980958534069' not in persistent cache.
# Key '151519623578653819' not in persistent cache.
# Key '5656159793750426107' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '3151838234736418775' not in persistent cache.
# Key '-4737650075832072067' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '6005030562325587928' not in persistent cache.
# Key '6333003551520896425' not in persistent cache.
# Key '-970921118120547395' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '452162227998828400' not in persistent cache.
# Key '-1274931516227689646' not in persistent cache.
# Key '-7232797896509106092' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '5239467464030352135' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-4693892539463785379' not in persistent cache.
# Key '-8155189961366346880' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-1746871428592387251' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '-3059043584793063638' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '5548308604572111642' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '8389361212230798029' not in persistent cache.
# Key '8496234110338532716' not in persistent cache.
# Key '1913549162205886303' not in persistent cache.
# Key '4645091030622532557' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '487224120098595183' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-7834810854940634702' not in persistent cache.
# Key '3692837871719999548' not in persistent cache.
# Key '-2140381396921896688' not in persistent cache.
# Key '2704783454678347705' not in persistent cache.
# Key '-4267518026081720340' not in persistent cache.
# Key '7541679746743938621' not in persistent cache.
# Key '-7359006144779533422' not in persistent cache.
# Key '-3528973880609029871' not in persistent cache.
# Key '-5689074698635785879' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '1025442618687200942' not in persistent cache.
# Key '-4206590758098085982' not in persistent cache.
# Key '3169499688258497142' not in persistent cache.
# Key '-1476678300813595276' not in persistent cache.
# Key '-2894184667838684894' not in persistent cache.
# Key '7332420673137485634' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-4369922239964883252' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7804738433950688413' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '4237429949400292028' not in persistent cache.
# Key '-6833223677952676464' not in persistent cache.
# Key '-8909835688173731243' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '-6010365731603318904' not in persistent cache.
# Key '-1111600034360892376' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '5258946151310052187' not in persistent cache.
# Key '5495915499180767760' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '7949454732980978489' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-2951192395614749173' not in persistent cache.
# Key '5822318103821154837' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '8339148329840236706' not in persistent cache.
# Key '-1953883477954253198' not in persistent cache.
# Key '-2342727041276001367' not in persistent cache.
# Key '2002991771393026221' not in persistent cache.
# Key '3869702113533103213' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '4274991165466337540' not in persistent cache.
# Key '-359367578055473263' not in persistent cache.
# Key '4760939361453863815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '1180000441729143934' not in persistent cache.
# Key '8556090888085727058' not in persistent cache.
# Key '-485077132884188172' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '2508318134774344510' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '-7729318241103231283' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-268203859524938574' not in persistent cache.
# Key '-6657214461494211938' not in persistent cache.
# Key '8800788336716972881' not in persistent cache.
# Key '8247984611309702017' not in persistent cache.
# Key '-4747190039750152207' not in persistent cache.
# Key '8709624618186438192' not in persistent cache.
# Key '3439759592405251650' not in persistent cache.
# Key '298841276928402327' not in persistent cache.
# Key '-3705838122422133536' not in persistent cache.
# Key '-2681292415122170463' not in persistent cache.
# Key '-6803345946525668317' not in persistent cache.
# Key '-4987909236512066995' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-3506388332823479911' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# Key '-8848908420190096885' not in persistent cache.
# Key '-1511159694031598159' not in persistent cache.
# Key '8061186469101104038' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '135509795061605057' not in persistent cache.
# Key '2392469803943013252' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-8471842394303570223' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-1700474917672077148' not in persistent cache.
# Key '-6413254182386569163' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '936479539669877367' not in persistent cache.
# Key '-3846211073976925971' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '1644758297689229805' not in persistent cache.
# Key '2144953980958534069' not in persistent cache.
# Key '151519623578653819' not in persistent cache.
# Key '5656159793750426107' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '3151838234736418775' not in persistent cache.
# Key '-4737650075832072067' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '6005030562325587928' not in persistent cache.
# Key '6333003551520896425' not in persistent cache.
# Key '-970921118120547395' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '452162227998828400' not in persistent cache.
# Key '-1274931516227689646' not in persistent cache.
# Key '-7232797896509106092' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '5239467464030352135' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-4693892539463785379' not in persistent cache.
# Key '-8155189961366346880' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-1746871428592387251' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '-3059043584793063638' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '5548308604572111642' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '8389361212230798029' not in persistent cache.
# Key '8496234110338532716' not in persistent cache.
# Key '1913549162205886303' not in persistent cache.
# Key '4645091030622532557' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '487224120098595183' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-7834810854940634702' not in persistent cache.
# Key '3692837871719999548' not in persistent cache.
# Key '-2140381396921896688' not in persistent cache.
# Key '2704783454678347705' not in persistent cache.
# Key '-4267518026081720340' not in persistent cache.
# Key '7541679746743938621' not in persistent cache.
# Key '-7359006144779533422' not in persistent cache.
# Key '-3528973880609029871' not in persistent cache.
# Key '-5689074698635785879' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '1025442618687200942' not in persistent cache.
# Key '-4206590758098085982' not in persistent cache.
# Key '3169499688258497142' not in persistent cache.
# Key '-1476678300813595276' not in persistent cache.
# Key '-2894184667838684894' not in persistent cache.
# Key '7332420673137485634' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-4369922239964883252' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7804738433950688413' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '4237429949400292028' not in persistent cache.
# Key '-6833223677952676464' not in persistent cache.
# Key '-8909835688173731243' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '-6010365731603318904' not in persistent cache.
# Key '-1111600034360892376' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '5258946151310052187' not in persistent cache.
# Key '5495915499180767760' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '7949454732980978489' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-2951192395614749173' not in persistent cache.
# Key '5822318103821154837' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '8339148329840236706' not in persistent cache.
# Key '-1953883477954253198' not in persistent cache.
# Key '-2342727041276001367' not in persistent cache.
# Key '2002991771393026221' not in persistent cache.
# Key '3869702113533103213' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '4274991165466337540' not in persistent cache.
# Key '-359367578055473263' not in persistent cache.
# Key '4760939361453863815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '1180000441729143934' not in persistent cache.
# Key '8556090888085727058' not in persistent cache.
# Key '-485077132884188172' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '2508318134774344510' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '-7729318241103231283' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-268203859524938574' not in persistent cache.
# Key '-6657214461494211938' not in persistent cache.
# Key '8800788336716972881' not in persistent cache.
# Key '8247984611309702017' not in persistent cache.
# Key '-4747190039750152207' not in persistent cache.
# Key '8709624618186438192' not in persistent cache.
# Key '3439759592405251650' not in persistent cache.
# Key '298841276928402327' not in persistent cache.
# Key '-3705838122422133536' not in persistent cache.
# Key '-2681292415122170463' not in persistent cache.
# Key '-6803345946525668317' not in persistent cache.
# Key '-4987909236512066995' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-3506388332823479911' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# Key '-8848908420190096885' not in persistent cache.
# Key '-1511159694031598159' not in persistent cache.
# Key '8061186469101104038' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '135509795061605057' not in persistent cache.
# Key '2392469803943013252' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-8471842394303570223' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-1700474917672077148' not in persistent cache.
# Key '-6413254182386569163' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '936479539669877367' not in persistent cache.
# Key '-3846211073976925971' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '1644758297689229805' not in persistent cache.
# Key '2144953980958534069' not in persistent cache.
# Key '151519623578653819' not in persistent cache.
# Key '5656159793750426107' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '3151838234736418775' not in persistent cache.
# Key '-4737650075832072067' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '6005030562325587928' not in persistent cache.
# Key '6333003551520896425' not in persistent cache.
# Key '-970921118120547395' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '452162227998828400' not in persistent cache.
# Key '-1274931516227689646' not in persistent cache.
# Key '-7232797896509106092' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '5239467464030352135' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-4693892539463785379' not in persistent cache.
# Key '-8155189961366346880' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-1746871428592387251' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '-3059043584793063638' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '5548308604572111642' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '8389361212230798029' not in persistent cache.
# Key '8496234110338532716' not in persistent cache.
# Key '1913549162205886303' not in persistent cache.
# Key '4645091030622532557' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '487224120098595183' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-7834810854940634702' not in persistent cache.
# Key '3692837871719999548' not in persistent cache.
# Key '-2140381396921896688' not in persistent cache.
# Key '2704783454678347705' not in persistent cache.
# Key '-4267518026081720340' not in persistent cache.
# Key '7541679746743938621' not in persistent cache.
# Key '-7359006144779533422' not in persistent cache.
# Key '-3528973880609029871' not in persistent cache.
# Key '-5689074698635785879' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '1025442618687200942' not in persistent cache.
# Key '-4206590758098085982' not in persistent cache.
# Key '3169499688258497142' not in persistent cache.
# Key '-1476678300813595276' not in persistent cache.
# Key '-2894184667838684894' not in persistent cache.
# Key '7332420673137485634' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-4369922239964883252' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7804738433950688413' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '4237429949400292028' not in persistent cache.
# Key '-6833223677952676464' not in persistent cache.
# Key '-8909835688173731243' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '-6010365731603318904' not in persistent cache.
# Key '-1111600034360892376' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '5258946151310052187' not in persistent cache.
# Key '5495915499180767760' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '7949454732980978489' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-2951192395614749173' not in persistent cache.
# Key '5822318103821154837' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '8339148329840236706' not in persistent cache.
# Key '-1953883477954253198' not in persistent cache.
# Key '-2342727041276001367' not in persistent cache.
# Key '2002991771393026221' not in persistent cache.
# Key '3869702113533103213' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '4274991165466337540' not in persistent cache.
# Key '-359367578055473263' not in persistent cache.
# Key '4760939361453863815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '1180000441729143934' not in persistent cache.
# Key '8556090888085727058' not in persistent cache.
# Key '-485077132884188172' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '2508318134774344510' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '-7729318241103231283' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-268203859524938574' not in persistent cache.
# Key '-6657214461494211938' not in persistent cache.
# Key '8800788336716972881' not in persistent cache.
# Key '8247984611309702017' not in persistent cache.
# Key '-4747190039750152207' not in persistent cache.
# Key '8709624618186438192' not in persistent cache.
# Key '3439759592405251650' not in persistent cache.
# Key '298841276928402327' not in persistent cache.
# Key '-3705838122422133536' not in persistent cache.
# Key '-2681292415122170463' not in persistent cache.
# Key '-6803345946525668317' not in persistent cache.
# Key '-4987909236512066995' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-3506388332823479911' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# Key '-8848908420190096885' not in persistent cache.
# Key '-1511159694031598159' not in persistent cache.
# Key '8061186469101104038' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '135509795061605057' not in persistent cache.
# Key '2392469803943013252' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-8471842394303570223' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-1700474917672077148' not in persistent cache.
# Key '-6413254182386569163' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '936479539669877367' not in persistent cache.
# Key '-3846211073976925971' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '1644758297689229805' not in persistent cache.
# Key '2144953980958534069' not in persistent cache.
# Key '151519623578653819' not in persistent cache.
# Key '5656159793750426107' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '3151838234736418775' not in persistent cache.
# Key '-4737650075832072067' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '6005030562325587928' not in persistent cache.
# Key '6333003551520896425' not in persistent cache.
# Key '-970921118120547395' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '452162227998828400' not in persistent cache.
# Key '-1274931516227689646' not in persistent cache.
# Key '-7232797896509106092' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '5239467464030352135' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-4693892539463785379' not in persistent cache.
# Key '-8155189961366346880' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-1746871428592387251' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '-3059043584793063638' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '5548308604572111642' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '8389361212230798029' not in persistent cache.
# Key '8496234110338532716' not in persistent cache.
# Key '1913549162205886303' not in persistent cache.
# Key '4645091030622532557' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '487224120098595183' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-7834810854940634702' not in persistent cache.
# Key '3692837871719999548' not in persistent cache.
# Key '-2140381396921896688' not in persistent cache.
# Key '2704783454678347705' not in persistent cache.
# Key '-4267518026081720340' not in persistent cache.
# Key '7541679746743938621' not in persistent cache.
# Key '-7359006144779533422' not in persistent cache.
# Key '-3528973880609029871' not in persistent cache.
# Key '-5689074698635785879' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '1025442618687200942' not in persistent cache.
# Key '-4206590758098085982' not in persistent cache.
# Key '3169499688258497142' not in persistent cache.
# Key '-1476678300813595276' not in persistent cache.
# Key '-2894184667838684894' not in persistent cache.
# Key '7332420673137485634' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-4369922239964883252' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7804738433950688413' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '4237429949400292028' not in persistent cache.
# Key '-6833223677952676464' not in persistent cache.
# Key '-8909835688173731243' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '-6010365731603318904' not in persistent cache.
# Key '-1111600034360892376' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '5258946151310052187' not in persistent cache.
# Key '5495915499180767760' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '7949454732980978489' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-2951192395614749173' not in persistent cache.
# Key '5822318103821154837' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '8339148329840236706' not in persistent cache.
# Key '-1953883477954253198' not in persistent cache.
# Key '-2342727041276001367' not in persistent cache.
# Key '2002991771393026221' not in persistent cache.
# Key '3869702113533103213' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '4274991165466337540' not in persistent cache.
# Key '-359367578055473263' not in persistent cache.
# Key '4760939361453863815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '1180000441729143934' not in persistent cache.
# Key '8556090888085727058' not in persistent cache.
# Key '-485077132884188172' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '2508318134774344510' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '-7729318241103231283' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-268203859524938574' not in persistent cache.
# Key '-6657214461494211938' not in persistent cache.
# Key '8800788336716972881' not in persistent cache.
# Key '8247984611309702017' not in persistent cache.
# Key '-4747190039750152207' not in persistent cache.
# Key '8709624618186438192' not in persistent cache.
# Key '3439759592405251650' not in persistent cache.
# Key '298841276928402327' not in persistent cache.
# Key '-3705838122422133536' not in persistent cache.
# Key '-2681292415122170463' not in persistent cache.
# Key '-6803345946525668317' not in persistent cache.
# Key '-4987909236512066995' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Key '-3506388332823479911' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# ...
# Key '-3839062773168674441' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '5207994141511934885' not in persistent cache.
# Key '-5964438139863663187' not in persistent cache.
# Key '1411652306492919937' not in persistent cache.
# Key '3243001953266953464' not in persistent cache.
# Key '1322081621231624392' not in persistent cache.
# Key '4299814684603839388' not in persistent cache.
# Key '-2334032199266679564' not in persistent cache.
# Key '-8536602538225956186' not in persistent cache.
# Key '4400761431267089298' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '2810276068515751124' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '-5869686815362973923' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '5281718822169088612' not in persistent cache.
# Key '-492000476383420446' not in persistent cache.
# Key '-9105356455340512510' not in persistent cache.
# Key '-1729266008983929386' not in persistent cache.
# Key '-214567563186726301' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-6604360417972149059' not in persistent cache.
# Key '-5390766173625846974' not in persistent cache.
# Key '-7694437903385842267' not in persistent cache.
# Key '-4838353758280686896' not in persistent cache.
# Key '-3747899054638139752' not in persistent cache.
# Key '-2483405957516346348' not in persistent cache.
# Key '-5753917696452903279' not in persistent cache.
# Key '3438600459170673585' not in persistent cache.
# Key '-5364350236098221816' not in persistent cache.
# Key '-3904962630070411887' not in persistent cache.
# Key '6634631679548570520' not in persistent cache.
# Key '-2869447416126469581' not in persistent cache.
# Key '7712315700525942217' not in persistent cache.
# Key '-550822804342076610' not in persistent cache.
# Key '4150317185708590457' not in persistent cache.
# Key '3508065062104666238' not in persistent cache.
# Key '6941156910976715521' not in persistent cache.
# Key '3402572448267262819' not in persistent cache.
# Key '-7810073603228419389' not in persistent cache.
# Key '1279680031236526905' not in persistent cache.
# Key '-6371583671075940289' not in persistent cache.
# Key '4699069956277028203' not in persistent cache.
# Key '-9018749798451461585' not in persistent cache.
# Key '-2167273985802158674' not in persistent cache.
# Key '-5204779741097912461' not in persistent cache.
# Key '-3209841070278375912' not in persistent cache.
# Key '-6210159681436140868' not in persistent cache.
# Key '2004581029403741634' not in persistent cache.
# Key '-1765397106580924122' not in persistent cache.
# Key '-7115045865671890647' not in persistent cache.
# Key '934278900156666253' not in persistent cache.
# Key '-1472817973833513761' not in persistent cache.
# Key '-8848908420190096885' not in persistent cache.
# Key '-1511159694031598159' not in persistent cache.
# Key '8061186469101104038' not in persistent cache.
# Key '-1334741214154667109' not in persistent cache.
# Key '135509795061605057' not in persistent cache.
# Key '2392469803943013252' not in persistent cache.
# Key '-4358687533621768466' not in persistent cache.
# Key '-6962392137741559981' not in persistent cache.
# Key '-1862719759423718509' not in persistent cache.
# Key '-8471842394303570223' not in persistent cache.
# Key '-2590480234417095189' not in persistent cache.
# Key '-1700474917672077148' not in persistent cache.
# Key '-6413254182386569163' not in persistent cache.
# Key '-356269328356522696' not in persistent cache.
# Key '1302789346118420150' not in persistent cache.
# Key '18714961984449870' not in persistent cache.
# Key '936479539669877367' not in persistent cache.
# Key '-3846211073976925971' not in persistent cache.
# Key '-5455513954628756505' not in persistent cache.
# Key '2700780764981941335' not in persistent cache.
# Key '-6046828199569343598' not in persistent cache.
# Key '1644758297689229805' not in persistent cache.
# Key '2144953980958534069' not in persistent cache.
# Key '151519623578653819' not in persistent cache.
# Key '5656159793750426107' not in persistent cache.
# Key '2451635809461812704' not in persistent cache.
# Key '3151838234736418775' not in persistent cache.
# Key '-4737650075832072067' not in persistent cache.
# Key '-5003638074900567832' not in persistent cache.
# Key '-3102729941297645752' not in persistent cache.
# Key '6005030562325587928' not in persistent cache.
# Key '6333003551520896425' not in persistent cache.
# Key '-970921118120547395' not in persistent cache.
# Key '-2898234973367660815' not in persistent cache.
# Key '1951227495203754304' not in persistent cache.
# Key '452162227998828400' not in persistent cache.
# Key '-1274931516227689646' not in persistent cache.
# Key '-7232797896509106092' not in persistent cache.
# Key '-3542506640555336266' not in persistent cache.
# Key '-5955664481038808909' not in persistent cache.
# Key '6852712027812447336' not in persistent cache.
# Key '272952374533775833' not in persistent cache.
# Key '-7387756074882563632' not in persistent cache.
# Key '5239467464030352135' not in persistent cache.
# Key '-1567842019344129965' not in persistent cache.
# Key '-4693892539463785379' not in persistent cache.
# Key '-8155189961366346880' not in persistent cache.
# Key '7794060680014221809' not in persistent cache.
# Baixando os dados disponíveis da API...
# WARNING:shelved_cache.persistent_cache:Key '6634631679548570520' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-485077132884188172' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3656895850336446982' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3839062773168674441' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4286117553226745511' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8308510912436772953' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6010365731603318904' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2921919712609543037' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5902568734686827575' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5906571424383233945' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1279680031236526905' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7804738433950688413' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7712315700525942217' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7178195916091430707' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7359006144779533422' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5869686815362973923' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4476756281532590047' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8536602538225956186' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2810276068515751124' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8380385779507201458' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-359367578055473263' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-9018749798451461585' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3692837871719999548' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6803345946525668317' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1334741214154667109' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4747190039750152207' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2869447416126469581' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4287441057892111058' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '550438081059754134' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4972959909053109102' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1476678300813595276' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8709624618186438192' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4358687533621768466' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2342727041276001367' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4987909236512066995' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1746871428592387251' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '597149801938341232' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3705838122422133536' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2483405957516346348' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7560778154843045638' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3243001953266953464' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3209841070278375912' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3508065062104666238' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3904962630070411887' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '936479539669877367' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-268203859524938574' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1644758297689229805' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8061186469101104038' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4059147678168542331' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2144953980958534069' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6440078203563016606' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6210159681436140868' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8339148329840236706' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '18714961984449870' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7332420673137485634' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1111600034360892376' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1953883477954253198' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8247984611309702017' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6604360417972149059' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4390188106042195674' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2334032199266679564' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4274991165466337540' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6941156910976715521' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1913549162205886303' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3027077024896063505' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5003638074900567832' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2451635809461812704' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2002991771393026221' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7694437903385842267' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5753917696452903279' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3542506640555336266' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7729318241103231283' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5656159793750426107' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1025442618687200942' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1862719759423718509' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6005030562325587928' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3747899054638139752' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2951192395614749173' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3438600459170673585' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6962392137741559981' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '934278900156666253' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5364350236098221816' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7387756074882563632' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-9092429322249363452' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5281718822169088612' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8800788336716972881' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2179395559409204097' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3121198894371990003' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4554052097153165351' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6669892196085879194' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1797693765103043170' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5925858020308619323' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3006168206391699872' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3138144946946327669' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2637736632688269269' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-748448511533836071' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2548156383158936556' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8578676435871277018' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1450232426047963801' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1720397949482467866' not in persistent cache.
#  Limpando e formatando os dados...
# Salvando em CSV...
# Dados prontos! Veja os primeiros registros:
#        country       date  PIB_USD  Renda_per_capita  Inflacao  \
# 0  Afghanistan 1960-01-01      NaN               NaN       NaN
# 1  Afghanistan 1961-01-01      NaN               NaN       NaN
# 2  Afghanistan 1962-01-01      NaN               NaN       NaN
# 3  Afghanistan 1963-01-01      NaN               NaN       NaN
# 4  Afghanistan 1964-01-01      NaN               NaN       NaN
#
#    Crescimento_PIB  Invest_Estrangeiro  Florestas_percentual  \
# 0              NaN                 NaN                   NaN
# 1              NaN                 NaN                   NaN
# 2              NaN                 NaN                   NaN
# 3              NaN                 NaN                   NaN
# 4              NaN                 NaN                   NaN
#
#    Energia_per_capita  Gasto_Militar_PIB  Taxa_Homicidios_100mil  \
# 0                 NaN                NaN                     NaN
# 1                 NaN                NaN                     NaN
# 2                 NaN                NaN                     NaN
# 3                 NaN                NaN                     NaN
# 4                 NaN                NaN                     NaN
#
#    Desemprego_percentual  Expectativa_vida  Gasto_saude_PIB
# 0                    NaN            32.799              NaN
# 1                    NaN            33.291              NaN
# 2                    NaN            33.757              NaN
# 3                    NaN            34.201              NaN
# 4                    NaN            34.673              NaN

# %%
# ==========================================================
# Importando bibliotecas necessárias
# ==========================================================
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv, find_dotenv

# Carrega as variáveis de ambiente a partir do arquivo .env
load_dotenv(find_dotenv())

# ==========================================================
# Definindo as credenciais do banco (Render)
# ==========================================================
host = os.getenv("HOST")
port = int(os.getenv("PORT"))
database = os.getenv("DATABASE")
user = os.getenv("USER")
password = os.getenv("PASSWORD")

# ==========================================================
# Criando a conexão com o PostgreSQL usando SQLAlchemy
# ==========================================================
engine = create_engine(
    f"postgresql://{user}:{password}@{host}:{port}/{database}"
)

# ==========================================================
# Salvando no banco (tabela: dados_banco_mundial)
# if_exists:
#   - 'replace' -> apaga e recria a tabela
#   - 'append' -> adiciona os dados
# ==========================================================
df.to_sql("tbl_dados_banco_mundial", engine, if_exists="replace", index=False)

print("✅ Dados salvos no banco Render com sucesso!")
# Out:
# ✅ Dados salvos no banco Render com sucesso!
