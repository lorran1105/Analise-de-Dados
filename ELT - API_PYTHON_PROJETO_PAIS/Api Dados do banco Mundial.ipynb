# %%
import wbdata
import pandas as pd
from datetime import datetime

# -------------------------------------------------------
#  Indicadores a coletar
# -------------------------------------------------------
indicadores = {
    # Econômicos

    'NY.GDP.MKTP.CD': 'PIB_USD',         # PIB (em USD)
    'NY.GNP.PCAP.CD': 'Renda_per_capita', # Renda per capita
    'FP.CPI.TOTL.ZG': 'Inflacao',         # Inflação
    'NY.GDP.MKTP.KD.ZG': 'Crescimento_PIB', # Crescimento do PIB
    'BX.KLT.DINV.CD.WD': 'Invest_Estrangeiro', # Investimento Estrangeiro

    # Ambientais

    #'EN.ATM.CO2E.PC': 'CO2_per_capita',  # CO2 per capita VALIDAR NÃO FUNCIONA
    'AG.LND.FRST.ZS': 'Florestas_percentual', # Percentual de florestas
    #'SH.H2O.SAFE.ZS': 'Agua_Potavel',     # Acesso à água potável VALIDAR NÃO FUNCIONA
    'EG.USE.PCAP.KG.OE': 'Energia_per_capita', # Consumo de energia per capita

    # Segurança e sociais

   'MS.MIL.XPND.GD.ZS': 'Gasto_Militar_PIB', # Gasto militar como % do PIB
   'VC.IHR.PSRC.P5': 'Taxa_Homicidios_100mil', # Taxa de homicídios por 100 mil habitantes
   'SL.UEM.TOTL.ZS': 'Desemprego_percentual', # Taxa de desemprego
   'SP.DYN.LE00.IN': 'Expectativa_vida',   # Expectativa de vida
   'SH.XPD.CHEX.GD.ZS': 'Gasto_saude_PIB'   # Gasto com saúde como % do PIB
}

# -------------------------------------------------------
# Coleta os dados (todos os anos disponíveis)
# -------------------------------------------------------
print("Baixando os dados disponíveis da API...")

try:
    # Chama a API do Banco Mundial sem o parâmetro data_date para pegar todos os anos
    df = wbdata.get_dataframe(indicators=indicadores)
    
except RuntimeError as e:
    print(f"Erro ao buscar dados: {e}")
    # Caso um erro ocorra, exiba a lista de indicadores que causaram o problema
    print("\nIndicadores problemáticos:")
    print(indicadores)

# -------------------------------------------------------
#  Limpeza e formatação
# -------------------------------------------------------
print(" Limpando e formatando os dados...")

# Resetando o índice para transformar as datas em colunas
df = df.reset_index()

# Converte a coluna 'date' para o formato datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# -------------------------------------------------------
# Exporta
# -------------------------------------------------------
print("Salvando em CSV...")

# Salva os dados em um arquivo CSV
df.to_csv("df_indicadores_mundiais_todos_anos.csv", index=False)

# -------------------------------------------------------
# Visualiza
# -------------------------------------------------------
print("Dados prontos! Veja os primeiros registros:")
print(df.head())
# Out:
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '5168068050973648953' not in persistent cache.
# Key '-9047847482570934831' not in persistent cache.
# Key '-3294011129259555376' not in persistent cache.
# Key '1116983819218081833' not in persistent cache.
# Key '-8369593743644023778' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '-3226779366672547019' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-1845671720161663658' not in persistent cache.
# Key '-14886856102900184' not in persistent cache.
# Key '-5473747228605991' not in persistent cache.
# Key '1603591722692106458' not in persistent cache.
# Key '-9160515647952920189' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '8690830464108018483' not in persistent cache.
# Key '8438546960269772019' not in persistent cache.
# Key '2688915908313110128' not in persistent cache.
# Key '588742055869127022' not in persistent cache.
# Key '-3309723544572252584' not in persistent cache.
# Key '-3111883342266784412' not in persistent cache.
# Key '2831546211702795560' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '-6179644254876753768' not in persistent cache.
# Key '-4913652553345326712' not in persistent cache.
# Key '455621629742134520' not in persistent cache.
# Key '1822646600142014311' not in persistent cache.
# Key '-5398888473321667618' not in persistent cache.
# Key '3796262127818194981' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-6707886018225708579' not in persistent cache.
# Key '9086539072797854154' not in persistent cache.
# Key '-3814000318900804809' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-6325796117025098058' not in persistent cache.
# Key '-6488831140775800726' not in persistent cache.
# Key '-3911129350292609157' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '401089927587948772' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-5604606202518782943' not in persistent cache.
# Key '-7962213582048176277' not in persistent cache.
# Key '4630020388597573201' not in persistent cache.
# Key '8900219796786942059' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '-2489352998922983942' not in persistent cache.
# Key '-8575646399624471334' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '-7798122833671760410' not in persistent cache.
# Key '-1330689207229128817' not in persistent cache.
# Key '2310354853967250102' not in persistent cache.
# Key '7876994469416331995' not in persistent cache.
# Key '-4898357365140161805' not in persistent cache.
# Key '989047810766158473' not in persistent cache.
# Key '-8490455345397131088' not in persistent cache.
# Key '-2270298121473076089' not in persistent cache.
# Key '7990335071216857230' not in persistent cache.
# Key '-6247651189563462550' not in persistent cache.
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# ...
# Key '-6766117746538924560' not in persistent cache.
# Key '407186172281099857' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '-4438971807644338254' not in persistent cache.
# Key '4489224848309304850' not in persistent cache.
# Key '4917469265513670177' not in persistent cache.
# Key '-6367153052243400678' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-178977604479316051' not in persistent cache.
# Key '-6033487707543118189' not in persistent cache.
# Key '7437306189014573900' not in persistent cache.
# Key '2954147343483243618' not in persistent cache.
# Key '-6236844095053648864' not in persistent cache.
# Key '-2694165164703013332' not in persistent cache.
# Key '59913021052298849' not in persistent cache.
# Key '-4904239444471032519' not in persistent cache.
# Key '907594486539158257' not in persistent cache.
# Key '-6861679287170588364' not in persistent cache.
# Key '-1280878557634327240' not in persistent cache.
# Key '-6794188166802701753' not in persistent cache.
# Key '5913999003716652214' not in persistent cache.
# Key '6781860629928200528' not in persistent cache.
# Key '2319425315338345634' not in persistent cache.
# Key '1745672902194586916' not in persistent cache.
# Key '-2793602815001496976' not in persistent cache.
# Key '1415538295419463884' not in persistent cache.
# Key '4719788092763110477' not in persistent cache.
# Key '-1134722010300691661' not in persistent cache.
# Key '2738908761113883193' not in persistent cache.
# Key '6965460977113491070' not in persistent cache.
# Key '1110950874049688932' not in persistent cache.
# Key '8153666553083654500' not in persistent cache.
# Key '-3281311068826732767' not in persistent cache.
# Key '-5282935273448063129' not in persistent cache.
# Key '-3705178112056670010' not in persistent cache.
# Key '-8425317139227134361' not in persistent cache.
# Key '8190422149849960083' not in persistent cache.
# Key '-1128689065132298760' not in persistent cache.
# Key '-1600534277033381590' not in persistent cache.
# Key '-7455044380097183728' not in persistent cache.
# Key '2121748564765813584' not in persistent cache.
# Key '-2433629603339873359' not in persistent cache.
# Key '-66724479407671913' not in persistent cache.
# Key '6015749516460508361' not in persistent cache.
# Key '-1001375347640659698' not in persistent cache.
# Key '-4519412974052223082' not in persistent cache.
# Key '-1579448736774841649' not in persistent cache.
# Key '8508702677115247519' not in persistent cache.
# Key '-4520444862188543967' not in persistent cache.
# Key '-7660762109294299053' not in persistent cache.
# Key '4989633162567363250' not in persistent cache.
# Key '3026311240536936691' not in persistent cache.
# Key '3049708884114907422' not in persistent cache.
# Key '2706478931767584255' not in persistent cache.
# Key '-281007599645439352' not in persistent cache.
# Key '-8645804299158619818' not in persistent cache.
# Key '6011552155507905335' not in persistent cache.
# Key '5759268651669658871' not in persistent cache.
# Key '-6320562589088469532' not in persistent cache.
# Key '-8917957987869551887' not in persistent cache.
# Key '-3063447884805749749' not in persistent cache.
# Key '5697699289597961552' not in persistent cache.
# Key '3897390349601766830' not in persistent cache.
# Key '-6220312959735495622' not in persistent cache.
# Key '-8636391190284325625' not in persistent cache.
# Key '4361277232806137686' not in persistent cache.
# Key '-2402085695329802436' not in persistent cache.
# Key '152330398042235940' not in persistent cache.
# Key '2384347504247192608' not in persistent cache.
# Key '8238857607310994746' not in persistent cache.
# Key '4807275075171851659' not in persistent cache.
# Key '-8206262261777226508' not in persistent cache.
# Key '3234720695116539066' not in persistent cache.
# Key '-4647758579680183029' not in persistent cache.
# Key '3198107622590886393' not in persistent cache.
# Key '-4114909858202588605' not in persistent cache.
# Key '-1685725331260721836' not in persistent cache.
# Key '-1193611254041145734' not in persistent cache.
# Key '7473831044154372598' not in persistent cache.
# Key '-8220610275592878315' not in persistent cache.
# Key '-7358580796290367100' not in persistent cache.
# Key '5136524142963578030' not in persistent cache.
# Key '-6813080643807439645' not in persistent cache.
# Key '713187044844054029' not in persistent cache.
# Key '-7952041206664263487' not in persistent cache.
# Key '2812066163980763160' not in persistent cache.
# Key '-5960589377426845915' not in persistent cache.
# Key '2238190956913557029' not in persistent cache.
# Key '1330347241192123638' not in persistent cache.
# Key '6727508542077591924' not in persistent cache.
# Key '-4825013266254461487' not in persistent cache.
# Key '2370508094311526416' not in persistent cache.
# Key '-4679302487690253952' not in persistent cache.
# Key '1029496836809340651' not in persistent cache.
# Key '-3541846630189872740' not in persistent cache.
# Key '-3959564807753643820' not in persistent cache.
# Key '182035050138040919' not in persistent cache.
# Key '-7952008377023829622' not in persistent cache.
# Key '-3641284280488356384' not in persistent cache.
# Key '-1903408900978127710' not in persistent cache.
# Key '-1225155162051216657' not in persistent cache.
# Key '-4002077256290153678' not in persistent cache.
# Baixando os dados disponíveis da API...
# WARNING:shelved_cache.persistent_cache:Key '-8850344073578217863' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-66724479407671913' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4269640210249581948' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7405762281004502977' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5318947022155832369' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8338049835633952855' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2793602815001496976' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-962288540426772040' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5368126327675403375' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8997184166086122919' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6707886018225708579' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5231026888320704060' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1836729276253017881' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1330689207229128817' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7428787401024152324' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8153666553083654500' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3695765003182375817' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-300879954749498445' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '401089927587948772' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6761680469203511622' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1822646600142014311' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7798122833671760410' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6925011951070308892' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3281311068826732767' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3705178112056670010' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2530021703781725796' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '907594486539158257' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4917469265513670177' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2688915908313110128' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '9001348018570513908' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2619365287547814299' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8575646399624471334' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6236844095053648864' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4989633162567363250' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7970154910492168324' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6766117746538924560' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6376566161117694871' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2121748564765813584' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1280878557634327240' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2270298121473076089' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4913652553345326712' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6488831140775800726' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8133486392358965594' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1579448736774841649' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '5984205608450437438' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2738908761113883193' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2489352998922983942' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8645804299158619818' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8508702677115247519' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7660762109294299053' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '59913021052298849' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3026311240536936691' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8206262261777226508' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3049708884114907422' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5834271501125372389' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1603591722692106458' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '407186172281099857' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6813080643807439645' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3294011129259555376' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2310354853967250102' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4898357365140161805' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-6179644254876753768' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8369593743644023778' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '370430575514794274' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4489224848309304850' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6011552155507905335' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-14886856102900184' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7121661465950818650' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2370508094311526416' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7577635673740274953' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3417162500040794246' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1001375347640659698' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8690830464108018483' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3311970420899887265' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-2694165164703013332' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1330347241192123638' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-3111883342266784412' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '897991436707727508' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '2457245834363464882' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4519412974052223082' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7990335071216857230' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4520444862188543967' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-5604606202518782943' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '1745672902194586916' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-9047847482570934831' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8190422149849960083' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3439260469536137111' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4101778625248618390' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8320311644551343027' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '263269408562829524' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '6344582781082286928' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7496401315315486348' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '8681104620353140321' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-7788709724797466217' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '3513595767319278278' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '7478663124232876520' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-8911925042701158986' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-4271922326094406451' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '-1641891212251684210' not in persistent cache.
# WARNING:shelved_cache.persistent_cache:Key '4949283087601252793' not in persistent cache.
#  Limpando e formatando os dados...
# Salvando em CSV...
# Dados prontos! Veja os primeiros registros:
#        country       date  PIB_USD  Renda_per_capita  Inflacao  \
# 0  Afghanistan 1960-01-01      NaN               NaN       NaN
# 1  Afghanistan 1961-01-01      NaN               NaN       NaN
# 2  Afghanistan 1962-01-01      NaN               NaN       NaN
# 3  Afghanistan 1963-01-01      NaN               NaN       NaN
# 4  Afghanistan 1964-01-01      NaN               NaN       NaN
#
#    Crescimento_PIB  Invest_Estrangeiro  Florestas_percentual  \
# 0              NaN                 NaN                   NaN
# 1              NaN                 NaN                   NaN
# 2              NaN                 NaN                   NaN
# 3              NaN                 NaN                   NaN
# 4              NaN                 NaN                   NaN
#
#    Energia_per_capita  Gasto_Militar_PIB  Taxa_Homicidios_100mil  \
# 0                 NaN                NaN                     NaN
# 1                 NaN                NaN                     NaN
# 2                 NaN                NaN                     NaN
# 3                 NaN                NaN                     NaN
# 4                 NaN                NaN                     NaN
#
#    Desemprego_percentual  Expectativa_vida  Gasto_saude_PIB
# 0                    NaN            32.799              NaN
# 1                    NaN            33.291              NaN
# 2                    NaN            33.757              NaN
# 3                    NaN            34.201              NaN
# 4                    NaN            34.673              NaN

# %%
# ==========================================================
# Importando bibliotecas necessárias
# ==========================================================
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv, find_dotenv

# Carrega as variáveis de ambiente a partir do arquivo .env
load_dotenv(find_dotenv())

# ==========================================================
# Definindo as credenciais do banco (Render)
# ==========================================================
host = os.getenv("DB_HOST_PROD")
port = int(os.getenv("DB_PORT_PROD"))
database = os.getenv("DB_NAME_PROD")
user = os.getenv("DB_USER_PROD")
password = os.getenv("DB_PASS_PROD")

# ==========================================================
# Criando a conexão com o PostgreSQL usando SQLAlchemy
# ==========================================================
engine = create_engine(
    f"postgresql://{user}:{password}@{host}:{port}/{database}"
)

# ==========================================================
# Salvando no banco (tabela: dados_banco_mundial)
# if_exists:
#   - 'replace' -> apaga e recria a tabela
#   - 'append' -> adiciona os dados
# ==========================================================
df.to_sql("tbl_dados_banco_mundial", engine, if_exists="replace", index=False)

print("✅ Dados salvos no banco Render com sucesso!")
# Out:
# ✅ Dados salvos no banco Render com sucesso!
