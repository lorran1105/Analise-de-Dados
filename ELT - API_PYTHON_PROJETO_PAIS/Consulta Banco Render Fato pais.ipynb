# %%
# ==========================================================
# Importando bibliotecas
# ==========================================================
import pandas as pd
from sqlalchemy import create_engine

# ==========================================================
# Credenciais do Render (mesmas que você usou)
# ==========================================================
host = "dpg-d39eabemcj7s73f0vcv0-a.oregon-postgres.render.com"
port = "5432"
database = "projeto_paises"
user = "user"
password = "QP7z5ILeinmGr76fDpSeNIiqLOeXL4WE"

# ==========================================================
# Criando a conexão
# ==========================================================
engine = create_engine(
    f"postgresql://{user}:{password}@{host}:{port}/{database}"
)

# ==========================================================
# Consultando os dados da tabela 'paises'
# ==========================================================
query = "SELECT * FROM fato_pais;"
df_lido = pd.read_sql(query, engine)

print("✅ Consulta realizada com sucesso!")
display(df_lido)
# Out:
# ✅ Consulta realizada com sucesso!
#     nome_resumido                     nome  \
# 0              RU                   Russia
# 1              AQ               Antarctica
# 2              CA                   Canada
# 3              CN                    China
# 4              US            United States
# ..            ...                      ...
# 245            CC  Cocos (Keeling) Islands
# 246            TK                  Tokelau
# 247            GI                Gibraltar
# 248            MC                   Monaco
# 249            VA             Vatican City
#
#                                  nome_oficial           capital     regiao  \
# 0                          Russian Federation            Moscow     Europe
# 1                                  Antarctica     Não informado  Antarctic
# 2                                      Canada            Ottawa   Americas
# 3                  People's Republic of China           Beijing       Asia
# ...
